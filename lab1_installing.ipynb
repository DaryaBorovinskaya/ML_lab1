# %% [markdown]
# Лабораторная работа 1. Линейная регрессия и факторный анализ
#
# Загрузка необходимых библиотек для выполнения лаборатоной работы

# %%
pip install pandas
# Out:
# ������� ������� ��������: 1251
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ������� ������� ��������: 1251
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kagglehub[pandas-datasets]
# Out:
# ������� ������� ��������: 1251
# ...
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [pyyaml]
#    ------------- -------------------------- 1/3 [pyyaml]
#    -------------------------- ------------- 2/3 [kagglehub]
#    -------------------------- ------------- 2/3 [kagglehub]
#    -------------------------- ------------- 2/3 [kagglehub]
#    ---------------------------------------- 3/3 [kagglehub]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ������� ������� ��������: 1251
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.7 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.7 MB 2.2 MB/s eta 0:00:04
#    -------- ------------------------------- 1.8/8.7 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.7 MB 1.8 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.7 MB 1.9 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.7 MB 2.3 MB/s eta 0:00:03
#    ------------------- -------------------- 4.2/8.7 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.7 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 6.0/8.7 MB 2.8 MB/s eta 0:00:01
# ...

# %%
pip install statsmodels
# Out:
# ������� ������� ��������: 1251
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.6 MB 3.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.6 MB 5.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.6 MB 5.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 7.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 7.7 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
# ...
